# %%
import  pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # for webscraping we installed beautifulsoup library

# %%
import requests 
from bs4 import BeautifulSoup

# %%
url ="https://www.reliancedigital.in/"
r=requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title data-rh="true">Online Electronic Shopping Store in India - Reliance Digital</title>
# <meta content="Buy Electronics Online at India's Best Online Electronic Shopping Store, Reliance Digital. Shop laptops, tvs, mobiles, cameras, home appliances etc from top brands." data-rh="true" name="Description"/><meta content="XnuZaT73IOPs_qlSbekjs3VI3pnJ7KJrqm44AnlQews" data-rh="true" name="google-site-verification"/><meta content="L4gW9Zs0u0Fi_e1wM-pxn5IF_xmz5t4iAq9gys8m4sE" data-rh="true" name="google-site-verification2"/><meta content="INDEX,FOLLOW" data-rh="true" name="robots"/><meta content="341116863058523" data-rh="true" property="fb:app_id"/><meta content="Reliance Digital" data-rh="true" property="og:site_name"/><meta content="en_EN" data-rh="true" property="og:locale"/><meta content="article" data-rh="true" property="og:type"/><meta content="Buy Electronics Online at India's Best Online Electronic Shopping Store, Reliance Digital. Shop laptops, tvs, mobiles, cameras, home appliances etc from top brands." data-rh="true" property="og:description"/><meta content="new" data-rh="true" property="product:condition"/><meta content="INR" data-rh="true" property="product:price:currency"/>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0, minimum-scale=1.0" name="viewport"/>
# <meta content="#e42529" name="theme-color"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="#e42529" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="A2HS Test" name="apple-mobile-web-app-title"/>
# <link href="/build/client/images/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link content="#e42529" href="/build/client/images/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="/manifest.json" rel="manifest"/>
# <link crossorigin="" href="https://www.reliancedigital.in" rel="preconnect"/>
# <link crossorigin="" href="//fonts.gstatic.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.googletagmanager.com" rel="preconnect"/>
# <link crossorigin="" href="http://b.scorecardresearch.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.google-analytics.com" rel="preconnect"/>
# <link crossorigin="" href="https://www.google.com" rel="preconnect"/>
# <link crossorigin="" href="https://stats.g.doubleclick.net" rel="preconnect"/>
# <link crossorigin="" href="https://www.google.co.in" rel="preconnect"/>
# <link href="//connect.facebook.net" rel="dns-prefetch"/>
# <link as="script" href="https://www.reliancedigital.in/build/client/web/js/HomePageW91014de5.js" rel="preload"/>
# <style id="client">@font-face{font-family:icomoon;font-style:normal;font-weight:400;src:url(https://www.reliancedigital.in/build/client/web/font/icomoon.d7fd10843a8e0c05ef55.woff);src:url(https://www.reliancedigital.in/build/client/web/font/icomoon.d7fd10843a8e0c05ef55.woff) format("woff"),url(https://www.reliancedigital.in/build/client/web/32a5ee8a76a8dc05cd25.svg?9uzgj4#icomoon) format("svg")}.header,header{min-width:1024px}.header{position:relative;top:0;width:100%;z-index:10000}.header__linkinfo{-webkit-box-pack:end;-ms-flex-pack:end;background:#e42529;color:#fff;display:-ms-flexbox;display:flex;display:-webkit-box;justify-content:flex-end;padding:4px 16px}.header__linkinfo__text{border-right:1px solid #dadada;font-size:13px;font-weight:600;padding:0 8px}.header__linkinfo__text a{color:#fff}.header__linkinfo__text:last-child{border-right:none}.header__maininfo{-webkit-box-pack:justify;-ms-flex-pack:justify;-webkit-box-align:end;-ms-flex-align:end;align-items:flex-end;background:#e42529;color:#fff;justify-content:space-between;margin-left:auto;margin-right:auto;padding:8px 16px 8px 48px;width:100%;z-index:10000}.header__maininfo,.header__maininfo__list{display:-webkit-box;display:-ms-flexbox;display:flex}.header__maininfo__list{-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:auto 0;min-width:150px}.header__maininfo__list .dropdown__item:hover .dropDown{display:block}.header__maininfo__list .dropdown__item:hover #dropdown-caret{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);transition:transform .1s,-webkit-transform .1s}.header__maininfo__list .dropdown__cart:hover .cartDropdown{display:block}.header__maininfo__list__item{border-left:1px solid #dadada;font-size:13px;font-weight:600;padding:0 8px;position:relative}.header__maininfo__list__item__username{vertical-align:middle}.header__maininfo__list__item a{color:inherit}.header__maininfo__list__item__number{background-color:#333;border-radius:50%;color:#fff;font-size:12px;height:22px;line-height:22px;margin-left:4px;position:absolute;text-align:center;top:-16px;width:22px;z-index:1}.header__maininfo__list__item__icon{font-size:16px;margin-right:8px}.header__maininfo__list__item:first-child{border-left:none}.linkInfo{background:#e42529;border-bottom:1px solid hsla(0,0%,100%,.3);color:#fff;display:-ms-flexbox;display:flex;display:-webkit-box;font-size:15px;line-height:25px}.linkInfo__item a{color:inherit}@media screen and (max-width:1281px){.linkInfo__item{-webkit-box-flex:1;-ms-flex-positive:1;border-right:1px solid hsla(0,0%,100%,.3);color:#fff;flex-grow:1;font-size:1vw;font-weight:700;line-height:20px;padding:8px 0;text-align:center}}@media screen and (min-width:1282px){.linkInfo__item{-webkit-box-flex:1;-ms-flex-positive:1;border-right:1px solid hsla(0,0%,100%,.3);color:#fff;flex-grow:1;font-size:14px;font-weight:700;line-height:20px;padding:8px 0;text-align:center}}.linkInfo__item:first-child{text-align:flex-end}.linkInfo__item:first-child,.linkInfo__item:last-child{-webkit-box-flex:2;-ms-flex-positive:2;border:none;flex-grow:2}.searchPanel{height:34px;margin:auto;min-width:200px;width:38%}.searchPanel__searchBox{border:0;border-radius:2px 0 0 2px;border-radius:2em;font-size:14px;height:36px;outline:0 none;padding:0 16px;width:100%}.searchPanel__search{background-color:#fff;border:1px solid rgba(0,0,0,0);color:#fff;display:inline-block;font-size:14px;font-weight:400;margin-bottom:0;margin-left:0;position:absolute;right:10px;top:7px;-webkit-transition:all .5s;-o-transition:all .5s;transition:all .5s}.dropdown{margin-left:4px;padding-bottom:8px;vertical-align:middle}#dropdown-caret:hover{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);transition:transform .1s,-webkit-transform .1s}.ripple{overflow:hidden;position:relative;will-change:transform}.ripple:after{background-image:-o-radial-gradient(circle,#333 15%,transparent 15.1%);background-image:radial-gradient(circle,#333 1 ...
# <link href="https://www.reliancedigital.in/build/client/web/css/HomePageW9c65ffb6.css" rel="stylesheet"/>
# <link href="https://www.reliancedigital.in" rel="canonical"/>
# <style data-styled="true" data-styled-version="5.3.5">.iTOHqf{background-color:#ffffff;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .jvmgbZ{color:#ffffff;background-color:#e42529;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .kSVrBK{font-size:13px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .dKXHpN{font-weight:500;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .kQMevB{color:#FFA41C;font-size:14px;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .EipDW{color:#003380;font-size:14px;font-weight:400;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# data-styled.g1[id="TextWeb__Text-sc-1cyx778-0"]{content:"iTOHqf,cXyRgU,jvmgbZ,kSVrBK,dKXHpN,kQMevB,EipDW,"}/*!sc*/
# .jGPgCM.jGPgCM.jGPgCM{width:14px;height:100%;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .guqocC.guqocC.guqocC{padding:12px 0px;width:auto;height:42px;cursor:pointer;}/*!sc*/
# @media (max-width:767px){.guqocC.guqocC.guqocC{padding:12px;width:100%;max-width:100%;}}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .bujlHC.bujlHC.bujlHC{margin:auto;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .dNOVTT.dNOVTT.dNOVTT{margin-bottom:24px;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .hRlEeq.hRlEeq.hRlEeq{padding:16px;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .dmsqlp.dmsqlp.dmsqlp{margin:4px 0px;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# .RMydb.RMydb.RMydb{padding:8px;width:25%;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# @media (min-width:768px) and (max-width:991px){}/*!sc*/
# @media (min-width:992px) and (max-width:1199px){}/*!sc*/
# @media (min-width:1200px){}/*!sc*/
# data-styled.g3[id="Block-sc-u1lygz-0"]{content:"jGPgCM,guqocC,bujlHC,dNOVTT,hRlEeq,dmsqlp,RMydb,"}/*!sc*/
# .fQfBiV.fQfBiV.fQfBiV{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# .ZRaHm.ZRaHm.ZRaHm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# @media (max-width:767px){}/*!sc*/
# data-styled.g12[id="Flex-sc-1suf6mt-0"]{content:"fQfBiV,ZRaHm,"}/*!sc*/
# .ghrjkT{cursor:pointer;}/*!sc*/
# data-styled.g34[id="PincodeWidget__PincodeBlock-sc-nh60to-0"]{content:"ghrjkT,"}/*!sc*/
# .pMWmb.pMWmb.pMWmb{position:fixed;z-index:111;}/*!sc*/
# data-styled.g36[id="PositionWeb__Position-sc-108igap-0"]{content:"pMWmb,"}/*!sc*/
# .egNLNA{background-color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media (max-width:768px){}/*!sc*/
# data-styled.g37[id="MarqueeSlider__MarqueeWrapper-sc-xag3r7-0"]{content:"egNLNA,"}/*!sc*/
# .hAWBZZ i{padding-right:2px;color:#FFA41C;font-size:14px;}/*!sc*/
# data-styled.g57[id="StarRating__StarRatingOuter-sc-1mfqajc-0"]{content:"hAWBZZ,"}/*!sc*/
# .kbrAAp{display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#ffffff;background:#003380;border:1px solid #003380;border-radius:2px;font-size:12px;font-weight:500;padding:4px 12px;text-transform:none;white-space:nowrap;}/*!sc*/
# .bBYZBv{display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#31812e;background:#effcf5;border:1px solid #31812e;border-radius:16px;font-size:9px;font-weight:500;padding:1px 6px;text-transform:uppercase;white-space:nowrap;}/*!sc*/
# data-styled.g124[id="Chip-sc-11o9f92-0"]{content:"kbrAAp,bBYZBv,"}/*!sc*/
# </style>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
# <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="6HLAC-46T3G-5C4WN-5E4UV-Q72GS",function(){function e(){if(!r){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,o.appendChild(e),r=!0}}function t(e){r=!0;var n,t,a,i,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(o,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",i=(a.frameElement||a).style,i.width=0,i.height=0,i.border=0,i.display="none",o.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void 0;",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=14,window.BOOMR.url=n+"6HLAC-46T3G-5C4WN-5E4UV-Q72GS";var i=document.currentScript||document.getElementsByTagName("script")[0],o=i.parentNode,r=!1,d=document.createElement("link");if(d.relList&&"function"==typeof d.relList.supports&&d.relList.supports("preload")&&"as"in d)window.BOOMR.snippetMethod="p",d.href=window.BOOMR.url,d.rel="preload",d.as="script",d.addEventListener("load",e),d.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!r)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),o.appendChild(d);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="eqausaddebwzijqacqlqauyaabssxl34-f-b3043e722-clienttons-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"36","ak.cp":"1265198","ak.ai":parseInt("760197",10),"ak.ol":"0","ak.cr":64,"ak.ipv":6,"ak.proto":"http/1.1","ak.rid":"1f98990c","ak.r":26697,"ak.a2":n,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"2401:4900:6320:6d94::","ak.cport":56485,"ak.gh":"23.3.70.23","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1697361788","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"30","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body><div id="root"><div class="Block-sc-u1lygz-0 jGPgCM PositionWeb__Position-sc-108igap-0 pMWmb" id="touchslide"><div></div></div><header class=""><ul class="header__linkinfo no-print"><li class="header__linkinfo__text"><a attr-tag="anchor" href="/locateus" id="RIL_FindAStore" rel="noopener noreferrer" target="_blank">Find a store</a></li><li class="header__linkinfo__text" id="RIL_BuyingGuides"><a attr-tag="anchor" href="https://www.reliancedigital.in/solutionbox" target="_blank">Buying guides</a></li><li class="header__linkinfo__text" id="RIL_ContactUs"><a attr-tag="anchor" href="/content/contactus" rel="noopener noreferrer" target="_blank">Contact us</a></li></ul><div class="header" id="header"><span id="downloadApp"></span><div class="header__maininfo" id="header__maininfo"><a aria-label="/" attr-tag="link" href="/" id="RIL_MainHeaderLogo" target=""><div class="" style="width:150px;height:50px;overflow:visible;position:relative;flex-basis:auto;padding-top:0px;margin:0px;display:block;background:transparent"><img alt="RelianceDigital Logo" class="" data-srcset="/build/client/images/loaders/rd_logo.svg" id="" src="/build/client/images/loaders/rd_logo.svg" style="vertical-align:baseline;max-width:100%;max-height:none;display:block;width:150px;height:50px" title="RelianceDigital Logo"/></div></a><div class="searchPanel no-print"><form class="suggestion flex"><div class="TextWeb__Text-sc-1cyx778-0 iTOHqf suggestion__box"><input autocomplete="off" class="suggestion__input searchPanel__searchBox" id="suggestionBoxEle" placeholder="Find your favorite products" type="text" value=""/><button class="searchPanel__search" id="RIL_HomeSearchButton" type="button"><i class="fa fa-search" style="color:#bbbbbb"></i></button></div></form></div><ul class="header__maininfo__list no-print"><li class="header__maininfo__list__item"><div class="TextWeb__Text-sc-1cyx778-0 cXyRgU"><div class="TextWeb__Text-sc-1cyx778-0 jvmgbZ Block-sc-u1lygz-0 PincodeWidget__PincodeBlock-sc-nh60to-0 guqocC ghrjkT"><div class="TextWeb__Text-sc-1cyx778-0 kSVrBK Block-sc-u1lygz-0 bujlHC">Select your Pin Code</div></div></div></li><li class="header__maininfo__list__item dropdown__cart"><a aria-label="/cart" attr-tag="link" class="pb__24" href="/cart" id="RIL_HeaderCart" target=""><i aria-hidden="true" class="fa fa-shopping-cart header__maininfo__list__item__icon"></i>Cart</a></li><li class="header__maininfo__list__item dropdown__item"><span class="pb__24 pointer" id="RIL_HeaderLoginAndMyAccount"><i aria-hidden="true" class="fa fa-user header__maininfo__list__item__icon"></i>Login</span></li></ul></div><nav><ul class="nav no-print"><li class="nav__container" id="RIL_MobilesTabletsNavigationNode"><div class="nav__title">Mobiles &amp; Tablets<span class="fa fa-angle-down ml__4"></span></div><div class="nav__description" style="display:none;background-image:url(/build/client/images/loader.gif)"><div class="flex"><div style="cursor:default"><ul><li class="nav__description__item"><a aria-label="/smartphones/c/S101711" attr-tag="link" class="nav__description__hoverULine" href="/smartphones/c/S101711" target="">Smartphones</a></li></ul><ul><li class="nav__description__item"><a aria-label="/wearable-technology/c/S101722" attr-tag="link" class="nav__description__hoverULine" href="/wearable-technology/c/S101722" target="">Smartwatches</a></li><li class="nav__description__subitem"><a aria-label="/page/apple-smartwatch" attr-tag="link" class="nav__description__hoverULine" href="/page/apple-smartwatch" target="">Apple</a></li><li class="nav__description__subitem"><a aria-label="/page/samsung-smartwatch" attr-tag="link" class="nav__description__hoverULine" href="/page/samsung-smartwatch" target="">Samsung</a></li><li class="nav__description__subitem"><a aria-label="/page/fire-boltt-smartwatch" attr-tag="link" class="nav__description__hoverULine" href="/page/fire-boltt-smartwatch" target="">Fireboltt</a></li><li class="nav__description__subitem"><a aria-label="/page/noise-smartwatch" ...
# <div class="screen-backdrop">
# <div class="screen-lock-box">
# <div class="pageloader" style="min-height:50vh"><div class="lines"><div class="bar animateDot"></div><div class="bar animateDot"></div><div class="bar animateDot"></div><div class="bar animateDot"></div></div></div>
# </div>
# </div>
# <div id="player" style="position: absolute; top: -9999px; left: -9999px;"></div>
# <script>window.__INITIAL_STATE__ = {"$header":{"siteLogoSection":[{"componentType":"SiteLogoComponent","visible":true,"name":"Site Logo","isDealTimerComponent":false,"dealTimerDetails":null,"url":"/","imageUrl":"/medias/logo-reliancedigital02.png?context=bWFzdGVyfGltYWdlc3wxNDQ2OXxpbWFnZS9qcGVnfGltYWdlcy9oNjgvaDAzLzkwOTU5ODU4NTY1NDIuanBnfGQxYmM2NDBkYjAzOTJmZmFiODZjYWVkODI1YjhmNTNkMTBmZjk0ZmNkMjQ4NWI3OGVlNDVhZGJkOGVkMWI3MTA","altText":"logo-reliancedigital.png","color":null,"textColor":null,"title":null,"alternateImageUrl":"","productName":null,"brandName":null,"categoryName":null,"maspRatio":null,"daspRatio":null}],"metaKeywords":null,"navigationBarSection":[{"componentType":"DigitalCategoryNavComponent","visible":true,"name":"Digital Category Navigation Component","isDealTimerComponent":false,"dealTimerDetails":null,"navigationLinks":[{"uid":"MobilesTabletsNavigationNode","name":"Mobiles And Tablets Menu","displayName":"Mobiles & Tablets","url":null,"target":"sameWindow","imageUrl":"/medias/Mobiles-Tablet-Menu-Banners-04-01-2021-01.jpg?context=bWFzdGVyfGltYWdlc3wxMTkxOTN8aW1hZ2UvanBlZ3xpbWFnZXMvaGM0L2gxNy85NTIwNDc1MzczNTk4LmpwZ3xjMmU0NzlmMWZjODQyMmFmNDZhMjA2NTUwZTVhNTI4ODcxMWVkZjM5YzgyNDY3YTE3ODU1OWM0NGQyY2E4MmVi","imageUrlLink":"/smartphones/c/S101711","navigationLinks":[{"uid":"MobilesTabletsLeftNavigationNode","name":"MobilesTablets Left Menu","displayName":"MobilesTablets Left Menu","url":"","target":null,"imageUrl":null,"imageUrlLink":null,"navigationLinks":[{"uid":"SmartPhonesNavNodeMenu","name":"Smartphones","displayName":"Smartphones","url":"/smartphones/c/S101711","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":[]},{"uid":"navigationNode_00000ENS","name":"Smart Wearables","displayName":"Smartwatches","url":"/wearable-technology/c/S101722","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":[{"uid":"navigationNode_00002KLC","name":"Apple","displayName":"Apple","url":"https://www.reliancedigital.in/page/apple-smartwatch","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00002KLD","name":"Samsung","displayName":"Samsung","url":"https://www.reliancedigital.in/page/samsung-smartwatch","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00002KLF","name":"Fireboltt","displayName":"Fireboltt","url":"https://www.reliancedigital.in/page/fire-boltt-smartwatch","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00002KLG","name":"Noise","displayName":"Noise","url":"https://www.reliancedigital.in/page/noise-smartwatch","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00002KLH","name":"Boat","displayName":"Boat","url":"https://www.reliancedigital.in/page/boat-smartwatch","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null}]},{"uid":"MobileTabletAccessoriesNavNodeMenu","name":"MobileTabletAccessories","displayName":"Accessories","url":null,"target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":[{"uid":"navigationNode_00000RS3","name":"Tablet Accessories","displayName":"Tablet Accessories","url":"https://www.reliancedigital.in/tablet-screen-protectors/c/S10171713","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00000N5L","name":"Mobile Accessories","displayName":"Mobile Accessories","url":"/campaign?page=Mobile_Accessories","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00000DW0","name":"Mobile Grips & Stands","displayName":"Mobile Grips & Stands","url":"/mobile-grips-stands/c/S10171814","target":"sameWindow","imageUrl":null,"imageUrlLink":null,"navigationLinks":null},{"uid":"navigationNode_00001JK1","name":"Car Mobile Holders","displayName":"Car Mobile Holders","url":"/car-mobile-holders/c/S10102815","targ ...
# <script>window.device = "pc"</script>
# <script>window.currentUrl = "/"</script>
# <script nomodule="" src="https://www.reliancedigital.in/build/client/web/js/coreaa67b854.js"></script>
# <script nomodule="" src="https://www.reliancedigital.in/build/client/web/js/obserPoly822c5e32.js"></script>
# <script>
#               window.addEventListener('load', function(){
#                 const scrpt9051062 = document.createElement('script');scrpt9051062.defer = true;scrpt9051062.src = "https://www.reliancedigital.in/build/client/web/js/vendor1e5369c92.js";document.head.appendChild(scrpt9051062);
#                 const scrpt9051063 = document.createElement('script');scrpt9051063.defer = true;scrpt9051063.src = "https://www.reliancedigital.in/build/client/web/js/vendor2cbccce92.js";document.head.appendChild(scrpt9051063);
#                 const scrpt9051064 = document.createElement('script');scrpt9051064.defer = true;scrpt9051064.src = "https://www.reliancedigital.in/build/client/web/js/HomePageW91014de5.js";document.head.appendChild(scrpt9051064);
#                 const scrpt9051065 = document.createElement('script');scrpt9051065.defer = true;scrpt9051065.src = "https://www.reliancedigital.in/build/client/web/js/client250dcf45.js";document.head.appendChild(scrpt9051065);
#               });
#             </script>
# <script>
#               "serviceWorker" in window.navigator && window.addEventListener("load",function(){window.navigator.serviceWorker.register("/sw.js").then(function (r) { let serviceWorker; if (r.installing) { serviceWorker = r.installing; } else if (r.waiting) { serviceWorker = r.waiting; } else if (r.active) { serviceWorker = r.active; } }).catch(function(e){console.error("ServiceWorker registration failed: ",e);});});
#               var installPromptEvent;window.addEventListener("beforeinstallprompt",function(e){installPromptEvent = e; if(document.querySelector("#downloadApp")) {document.querySelector("#downloadApp").style.visibility = "visible";}/*console.log("beforeinstallprompt Event fired", installPromptEvent);*/document.querySelector("#downloadApp") && document.querySelector("#downloadApp").addEventListener("click",function(){installPromptEvent && installPromptEvent.prompt(); }),e.userChoice.then(function(e){("dismissed"===e.outcome || e === undefined)?(console.log("User cancelled home screen install")):(document.querySelector("#downloadApp").style.visibility = "hidden",console.log("User added to home screen"))})});
#             </script>
# <script type="application/ld+json">
#             {"@context": "http://schema.org","@type": "WebSite","url": "https://www.reliancedigital.in/","potentialAction": {"@type": "SearchAction","target": "https://www.reliancedigital.in/search?q={search_term_string}","query-input": "required name=search_term_string"}}
#             </script>
# </body></html>

# %%
<div class="nav__title">Home Appliances<span class="fa fa-angle-down ml__4"></span></div>
